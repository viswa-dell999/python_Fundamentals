# %%
name='Viswa'
lname="Bagati"
print(name)
print(lname)
# Out:
# Viswa
# Bagati

# %%
type(name)
# Out:
# str

# %%
fullname="viswanadham bagati"

# %%
print(fullname)
# Out:
# viswanadham bagati

# %%
print(fullname.title())
# Out:
# Viswanadham Bagati

# %%
print(fullname.upper())
# Out:
# VISWANADHAM BAGATI

# %%
print(fullname.lower())
# Out:
# viswanadham bagati
